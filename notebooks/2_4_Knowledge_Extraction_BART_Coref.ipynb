# %%
#@title Mount your Google Drive
# If you run this notebook locally or on a cluster (i.e. not on Google Colab)
# you can delete this cell which is specific to Google Colab. You may also
# change the paths for data/logs in Arguments below.
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install transformers datasets evaluate rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 89.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 47.7 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 12.8 MB/s eta 0:00:00
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.8 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.3 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.4 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 76.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 35.4 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 17.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=87c90bdc9ed790a43733241ffd62c551d404eb428ec62ab071d55d57c5f95891
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, rouge_score, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 rouge_score-0.1.2 tokenizers-0.13.3 transformers-4.28.1 xxhash-3.2.0 yarl-1.9.2

# %%
import sys
import os
import shutil
import warnings
import pandas as pd
import numpy as np
import json
import torch
import evaluate

from transformers import (
  AutoModelForSeq2SeqLM, 
  DataCollatorForSeq2Seq,
  Seq2SeqTrainingArguments, 
  Seq2SeqTrainer,
  AutoTokenizer, 
  pipeline
) 

from pathlib import Path
from datasets import load_dataset, load_metric

# %%
# Paths

PROJ_DIR = Path('/content/gdrive/MyDrive/IFT6759/quick-recipe')
LOG_DIR = PROJ_DIR / 'logs'

LOG_DIR.mkdir(parents=True, exist_ok=True) 

if str(PROJ_DIR) not in sys.path:
    sys.path.insert(0, str(PROJ_DIR))

MODEL_DIR = PROJ_DIR / 'models'
DATA_DIR = PROJ_DIR / 'youcook2'
MODEL_SAVE_DIR = MODEL_DIR / 'youcook_BART_Coref'
LOG_SAVE_DIR = LOG_DIR / 'youcook_BART_Coref'

MODEL_SAVE_DIR.mkdir(parents=True, exist_ok=True) 
LOG_SAVE_DIR.mkdir(parents=True, exist_ok=True) 

ANNOTATED_DF_PATH = str(DATA_DIR / 'reviewed_0812_coref_aligned.csv')
SPLIT_DF_PATH = str(DATA_DIR / 'train_val_split.csv')
TRAIN_FRAC = 0.7
MAX_INPUT_LENGTH = 1024
MAX_SUMMARY_LENGTH = 128

RANDOM_SEED = 23456
np.random.seed(RANDOM_SEED)

# %%
df = pd.read_csv(ANNOTATED_DF_PATH)

# %%
key_sentences = df[df['IsUsefulSentence'] == 1]

# %%
len(key_sentences)
# Out:
# 3569

# %%
split_df = pd.read_csv(SPLIT_DF_PATH)

train_video_urls = list(split_df[split_df['Split'] == 'train']['VideoUrl'].values)
test_video_urls = list(split_df[split_df['Split'] == 'val']['VideoUrl'].values)

train_df = df[df['VideoUrl'].isin(train_video_urls)]
test_df = df[df['VideoUrl'].isin(test_video_urls)]

train_sentences, train_instructions = train_df[train_df['IsUsefulSentence'] == 1]['Sentence_Coref'].to_numpy(), train_df[train_df['IsUsefulSentence'] == 1]['Key steps'].to_numpy()
test_sentences, test_instructions = test_df[test_df['IsUsefulSentence'] == 1]['Sentence_Coref'].to_numpy(), test_df[test_df['IsUsefulSentence'] == 1]['Key steps'].to_numpy()

# Split val set from within train
indices = list(range(len(train_sentences)))
np.random.shuffle(indices)
train_len = int(TRAIN_FRAC * len(train_sentences))

val_sentences, val_instructions = train_sentences[indices[train_len:]], train_instructions[indices[train_len:]]
train_sentences, train_instructions = train_sentences[indices[:train_len]], train_instructions[indices[:train_len]]

# %%
# indices = list(range(len(key_sentences)))
# np.random.shuffle(indices)
# train_len = int(TRAIN_FRAC * len(key_sentences))

# %%
# sentences, instructions = key_sentences['Sentence'].to_numpy() , key_sentences['Key steps'].to_numpy()

# %%
# train_sentences, train_instructions = sentences[:train_len], instructions[:train_len]
# val_sentences, val_instructions = sentences[train_len:], instructions[train_len:]

# %%
len(train_sentences), len(val_sentences), len(train_instructions), len(val_sentences)
# Out:
# (1755, 753, 1755, 753)

# %%
checkpoint = "sshleifer/distilbart-xsum-12-3"
tokenizer = AutoTokenizer.from_pretrained(checkpoint, model_max_length=MAX_INPUT_LENGTH)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.51k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
prefix = ""

def preprocess_function(examples, max_input_length=MAX_INPUT_LENGTH, max_summary_length=MAX_SUMMARY_LENGTH):
    inputs = [prefix + doc for doc in examples["text"]]
    
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    labels = tokenizer(text_target=examples["summary"], max_length=max_summary_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenizer('hi how are you', max_length=MAX_INPUT_LENGTH, truncation=True)
# Out:
# {'input_ids': [0, 3592, 141, 32, 47, 2], 'attention_mask': [1, 1, 1, 1, 1, 1]}

# %%
def generate_encodings(sentences, instructions, tokenizer, max_input_length=MAX_INPUT_LENGTH, max_summary_length=MAX_SUMMARY_LENGTH):
    examples = []
    for sentence, instruction in zip(list(sentences), list(instructions)):
        try:            
            sentence = str(sentence)
            instruction = str(instruction)
            example = {'text': sentence, 'summary': instruction}
            model_inputs = tokenizer(sentence, max_length=max_input_length, truncation=True)
            labels = tokenizer(text_target=instruction, max_length=max_summary_length, truncation=True)
            model_inputs['labels'] = labels['input_ids']
            example['input_ids'] = model_inputs['input_ids']
            example['attention_mask'] = model_inputs['attention_mask']
            example['labels'] = model_inputs['labels']
            examples.append(example)
        except Exception as e:
            print(sentence, instruction)
            continue
    
    return examples

# %%
class YouCookDatasetForKnowledgeExtraction(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        item = self.encodings[idx]
        item['input_ids'] = torch.tensor(item['input_ids'])
        item['attention_mask'] = torch.tensor(item['attention_mask'])
        item['labels'] = torch.tensor(item['labels'])
        return item

    def __len__(self):
        return len(self.encodings)

# %%
train_encodings = generate_encodings(train_sentences, train_instructions, tokenizer)
val_encodings = generate_encodings(val_sentences, val_instructions, tokenizer)
test_encodings = generate_encodings(test_sentences, test_instructions, tokenizer)

train_dataset = YouCookDatasetForKnowledgeExtraction(train_encodings)
val_dataset = YouCookDatasetForKnowledgeExtraction(val_encodings)
test_dataset = YouCookDatasetForKnowledgeExtraction(test_encodings)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

# %%
rouge = evaluate.load("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)

    return {k: round(v, 4) for k, v in result.items()}

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/716M [00:00<?, ?B/s]

# %%
MODEL_SAVE_DIR, LOG_SAVE_DIR
# Out:
# (PosixPath('/content/gdrive/MyDrive/IFT6759/quick-recipe/models/youcook_BART_Coref'),
#  PosixPath('/content/gdrive/MyDrive/IFT6759/quick-recipe/logs/youcook_BART_Coref'))

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=str(MODEL_SAVE_DIR),
    logging_dir=str(LOG_SAVE_DIR),
    logging_steps=10,
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    weight_decay=0.01,
    save_strategy="epoch",
    save_total_limit=3,
    # load_best_model_at_end=False,
    num_train_epochs=6,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=False,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 06:19, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.331600</td>
#       <td>1.976171</td>
#       <td>0.412800</td>
#       <td>0.190000</td>
#       <td>0.398900</td>
#       <td>0.398200</td>
#       <td>12.827400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.641600</td>
#       <td>1.830468</td>
#       <td>0.430200</td>
#       <td>0.206400</td>
#       <td>0.415300</td>
#       <td>0.414800</td>
#       <td>12.573700</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.598900</td>
#       <td>1.783984</td>
#       <td>0.434300</td>
#       <td>0.209800</td>
#       <td>0.420500</td>
#       <td>0.420400</td>
#       <td>12.761000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.421500</td>
#       <td>1.774660</td>
#       <td>0.437300</td>
#       <td>0.216100</td>
#       <td>0.421400</td>
#       <td>0.421800</td>
#       <td>12.682600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.152300</td>
#       <td>1.770243</td>
#       <td>0.436000</td>
#       <td>0.210900</td>
#       <td>0.422200</td>
#       <td>0.422300</td>
#       <td>12.770300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.197300</td>
#       <td>1.768727</td>
#       <td>0.436800</td>
#       <td>0.213100</td>
#       <td>0.423600</td>
#       <td>0.423900</td>
#       <td>12.776900</td>
#     </tr>
#   </tbody>
# </table><p>
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# TrainOutput(global_step=330, training_loss=1.687768233906139, metrics={'train_runtime': 382.6792, 'train_samples_per_second': 27.517, 'train_steps_per_second': 0.862, 'total_flos': 1022177715763200.0, 'train_loss': 1.687768233906139, 'epoch': 6.0})

# %% [markdown]
# ## Inference and metrics calculation

# %%
MODEL_CHECKPOINT_PATH = str(MODEL_SAVE_DIR / 'checkpoint-275')

# %%
summarizer = pipeline("summarization", model=MODEL_CHECKPOINT_PATH)

# %%
total_true_pos = 0
total_num_predicted = 0
total_num_gold = 0
text_list = []
summary_list = []
predictions_list = []
true_positive_list = []
num_predicted_list = []
num_gold_list = []

for index in range(len(test_dataset)):
  if (index+1) % 50 == 0:
    print(f"Processing example {index+1}")
  text = test_dataset[index]['text']
  summary = test_dataset[index]['summary']
  text_words = text.split(' ')
  summary_words = summary.split(' ')
  max_len = len(text_words)
  predictions = summarizer(text, min_length=3, max_length=max_len)
  predicted_words = set(predictions[0]['summary_text'].split(' '))
  # print("Text: ", text)
  # print("Predicted: ", predictions)
  # print("Actual: ", summary)
  true_pos = len(set(predicted_words) & set(summary_words))
  num_predicted = len(set(predicted_words))
  num_gold = len(set(summary_words))
  total_true_pos += true_pos
  total_num_predicted += num_predicted
  total_num_gold += num_gold
  text_list.append(text)
  summary_list.append(summary)
  predictions_list.append(predictions[0]['summary_text'])
  true_positive_list.append(true_pos)
  num_predicted_list.append(num_predicted)
  num_gold_list.append(num_gold)
# Out:
# <ipython-input-18-b4fc7bd9ae1e>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['input_ids'] = torch.tensor(item['input_ids'])
# <ipython-input-18-b4fc7bd9ae1e>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['attention_mask'] = torch.tensor(item['attention_mask'])
# <ipython-input-18-b4fc7bd9ae1e>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(item['labels'])
# Processing example 50
# Processing example 100
# Processing example 150
# Processing example 200
# Processing example 250
# Processing example 300
# Processing example 350
# Processing example 400
# Processing example 450
# Processing example 500
# Processing example 550
# Processing example 600
# Processing example 650
# Processing example 700
# Processing example 750
# Processing example 800
# Processing example 850
# Processing example 900
# Processing example 950
# Processing example 1000
# Processing example 1050

# %%
predictions_list
# Out:
# ['place dough in caputo flour',
#  'flip pizza',
#  'sprinkle the surface',
#  'squish pizza',
#  'dimple pizza',
#  'Do a quick stretch while rotating',
#  'put pizza on the backs of hands',
#  'put sauce on pizza',
#  'put cheese on',
#  'put on olive oil',
#  'place pizza on stone',
#  'rotrot pizza',
#  'put olive oil directly on',
#  'cut pizza',
#  'stretch dough',
#  'add tomato sauce',
#  'finish margarita pizza',
#  'add tomato sauce',
#  'leave pizza',
#  'lay bread on bread',
#  'lay basil',
#  'Press down the mixture',
#  'pop dough in oven',
#  'keep pizza on pizza stone',
#  'cut into bite size pieces',
#  'take peanut butter',
#  'combine ingredients',
#  'put in chili sauce',
#  'put in soy sauce',
#  'mix salt',
#  'heat pan',
#  'put in garlic',
#  'put ginger in chicken',
#  'remove fat',
#  'put bread in fan',
#  'stir fry mixture',
#  'coast',
#  'add peanut butter mixture',
#  'cook peanut butter',
#  'drain water',
#  'put tofu on paper towel',
#  'take green onion, chopped up carrot',
#  'combine egg whites',
#  'take green onion',
#  'add water',
#  'add total win',
#  'add George tofu',
#  'add filling',
#  ' moisten edges',
#  'Pinch tomatoes',
#  'Press for bread',
#  'put pot stickers on tray',
#  'heat oil; add pot stickers',
#  'cook mixture',
#  'add half of dough',
#  'add water',
#  'cook dough',
#  'cover mixture',
#  'cook mixture',
#  'remove and put on cooling rack',
#  'add water',
#  'add rice vinegar, soy sauce',
#  'add ginger, toasted sesame oil',
#  'add crushed red pepper',
#  'add whiskey',
#  'add oil',
#  'take broiling pan',
#  'put foil on pan',
#  'line colby in pan',
#  'stick rice greens, meat',
#  'dip chicken into bread crumbs, butter',
#  'add olive oil to chicken',
#  'sprinkle salt',
#  'spoon chicken',
#  'slice mozzarella',
#  'cover up foil',
#  'pop in oven',
#  'add panko',
#  'coat cutlet with cheese and bread crumb mixture',
#  'fry cutlets',
#  'drain fish on paper towels',
#  'put dough on cookie sheet',
#  'take marinade',
#  'add mozzarella cheese',
#  'put marinade in oven',
#  'dress with extra virgin olive oil, salt, pepper',
#  'marinate noodles',
#  'lit the main burners',
#  'heat tomato sauce',
#  'transfer chicken to pan',
#  'transfer chicken breast into sauce',
#  'move pan to centre of grill',
#  'close lid, cook uncovered',
#  'add parmesan cheese',
#  'dice onion, green pepper, red pepper',
#  'add bay leaf',
#  'stir mixture',
#  'add clam juice',
#  'add clams',
#  'mix',
#  'add half and half',
#  'mix ingredients',
#  'add flour',
#  'stir clam chowder',
#  'add porchester sauce',
#  'add hot sauce',
#  'mix ingredients',
#  'add salt, black peppercorn',
#  'melt butter',
#  'stir garlic',
#  'add celery, spices',
#  'add white pepper, bay leaf',
#  'stir chowder',
#  'lower flame; add flour',
#  'cook chowder',
#  'cook chowder',
#  'cook redskin potatoes',
#  'stir cream',
#  'add chowder',
#  'heat mixture',
#  'add chopped, diced, celery, onions',
#  'add cornstarch',
#  'stir into butter mixture',
#  'add half and half to mixture',
#  'throw in sea salt',
#  'put bacon in pot',
#  'put pancetta in',
#  'saute pancetta',
#  'take carrots, celery',
#  'add basil, marjoram',
#  'add chopped garlic',
#  'move chopped garlic, bay leaf',
#  'add white wine to pan',
#  'reduce liquid',
#  'add soak beans',
#  'pour chicken stock',
#  'bring to boil',
#  'cook mixture',
#  'start in canned tomatoes',
#  'pour tomatoes through pressure cooker',
#  'Cook pasta',
#  'put potatoes in cold water',
#  'foul oil',
#  'take egg yol',
#  'add english mustard, white wine vinegar',
#  'put oil in bowl',
#  'add oil',
#  'chop capers, gherkins, tarragon',
#  'add chervil, chives, mayonnaise',
#  'add salt and pepper',
#  'taste tartar sauce',
#  'take knife',
#  'drain batter',
#  'add flavour',
#  'add beer',
#  'add salt, pepper',
#  'cover with tea towel',
#  'skate fish',
#  'cut in bones',
#  'put chips in fryer',
#  'flip through the flower',
#  'add flower to batter',
#  'drain chips',
#  'put cod in fryer',
#  'fry fish',
#  'add salt, lemon accord, peas',
#  'chop fish',
#  'dump in beer',
#  'add salt',
#  'add flour',
#  'crank deep fryer',
#  'add cornstarch',
#  'dump halibut into flour',
#  'fry fish',
#  'add water',
#  'add beef stock',
#  'dissolve beef stock',
#  'heat olive oil',
#  'season beef',
#  'add pepper',
#  'add meat to pan',
#  'leave oil in pan',
#  'add onion',
#  'add garlic, ginger, chili',
#  'brown onions',
#  'add japanese barbecue sauce',
#  'mix mixture',
#  'Add noodles to stock',
#  'cut beef',
#  'add soup and noodles',
#  'place meat on bowl',
#  'spoon on beef',
#  'add cashew nuts',
#  'remove brown potatoes',
#  'add mustard seats, human seats',
#  'add onions, curry leaves',
#  'fry green chilies, ginger',
#  'fry turmeric powder',
#  'cook mixture',
#  'add chopped coriander',
#  'spread pan',
#  'spread dosa batter',
#  'add potato masala',
#  'cover with half half; cook lusa; serve hot with sambaran coconut chutney',
#  'mix rice flour',
#  'add sudie',
#  'add fuel',
#  'add salt, cumin seeds',
#  'add pinch of foo',
#  'add water',
#  'add chopped ginger',
#  'chop green chilies',
#  'mix ingredients',
#  'add black pepper',
#  'add grated coconut',
#  'add coconut',
#  'add mill',
#  'add oil to pan',
#  'apply oil on edges of oil',
#  'apply potato to the dozer',
#  'put oil in',
#  'saute onion',
#  'add jalapeno, garlic',
#  'put meat on top of onion',
#  'add beer',
#  'break bread',
#  'add cumin, allspice',
#  'add worcestershire, dry mustard',
#  'add tomato paste',
#  'add tomato paste',
#  'take mixture',
#  'add apple cider vinegar',
#  'move eggs aside',
#  'heat hot dogs inside skillet',
#  'throw weenies',
#  'bring to simmer',
#  'get doughnuts',
#  'add chili',
#  'stir mixture',
#  'add pickled jalapeno',
#  'add bok, choy, onion, sesame oil; cook noodles',
#  'stir fry the wantan noodle, bean sprouts, scallions, soy sauce, sesame oil',
#  'put noodles in',
#  'stir the mixture',
#  'add sauce',
#  'add garlic, shallots, meat',
#  'add turbo cars, cornstarch, potato starch',
#  'add vegetable oil, oyster sauce',
#  'crack pepper',
#  'process mixture',
#  'mix with water',
#  ' soak shiitake mushrooms in hot',
#  'add broth',
#  'bring to a full pot',
#  'wash bones',
#  'boil bones',
#  'add salt',
#  'cut onions, radish',
#  'take mushroom',
#  'prepate a stack of a wrapper',
#  'sop eggs',
#  'take fat white',
#  'Add egg noodles to boiling water',
#  'cook mixture',
#  'blanched beans, bok choy',
#  'add jessue slices',
#  'ladle hot soup on top',
#  'rinse off escargot',
#  'pat dry bread',
#  'press escargot',
#  'add chives, salt',
#  'add sherry',
#  'Cook escargot',
#  'marinate clean calamari in olive oil, thyme, salt',
#  'add melon ball',
#  'add salted water',
#  ' assemble vinaigrette',
#  'add soy sauce, rice wine vinegar',
#  'add',
#  'add mirren, sesame paste, molasses',
#  'whisk in sesame oil',
#  'add olive oil',
#  'add calamari',
#  'flip tentacles',
#  'add cherries',
#  'brown potatoes',
#  'add salt, sumac',
#  'chop calamari',
#  'pop cherries',
#  'add potatoes to bowl',
#  'mix calamari',
#  'disturinate',
#  'add flour',
#  'put on paper towel lined plate',
#  'sprinkle with salt',
#  'put on pre eighty platter',
#  'place pork chops between saran wrap',
#  'add salt and pepper',
#  'put flower on one plate',
#  'dunk pork chop in egg',
#  'put pork chops in oil',
#  'flip chicken',
#  'peel potatoes',
#  'add brown bruise',
#  'Boil potatoes',
#  'add flower and egg',
#  'mix potato flour, egg',
#  'add salt',
#  'make individual dumplings',
#  'throw dumplings back in boiling water',
#  'drain water',
#  'season with black pepper, basil',
#  'add dash assault',
#  'add parmesan cheese',
#  'add red pepper',
#  'add',
#  'mix ingredients',
#  'crack egg, heavy cream',
#  'add water',
#  'coat parmesan cheese',
#  'flip dish',
#  'layer pork cutlets in fryer oil',
#  'get excess oil',
#  'cool on paper',
#  'fry potatoes',
#  'put platter',
#  'squee',
#  'pressure tomato',
#  'pour over the dough',
#  'add basil',
#  'add salt',
#  'blend the mixture',
#  'add cheese and apple',
#  'chop onion',
#  'heat pan',
#  'add butter, olive oil',
#  'add olive oil',
#  'cook onion',
#  'take out the seats',
#  'chop seeds',
#  'add water',
#  'add vegetables',
#  'cover it with',
#  'run through roasted bell pepper',
#  'add roasted bell pepper',
#  'blend bell pepper',
#  'add parsley',
#  'add paprika, pepper rica',
#  'add brown sugar',
#  'add soap',
#  'add parsley, cilantro',
#  'slice slices',
#  'put in oven',
#  'heat pan',
#  'add oil',
#  'toast bread',
#  'add cheese',
#  'add rasberry coulis',
#  'put on toast',
#  'put fig vinegar',
#  'add olive oil, pepper, salt',
#  ' fry pita bread',
#  'put bread on paper towel',
#  'pick the ends',
#  'place lettuce in bowl',
#  'place salad in fridge',
#  'mix dressing',
#  'cut half',
#  'rinse potatoes',
#  'drain rice into cold water',
#  'add salt',
#  'bring to a boil',
#  'cook mixture',
#  'cut butter',
#  'check with spoon',
#  'drain rice',
#  'turn heat on medium',
#  'match with wire potato masher',
#  'dump pepper, salt',
#  'mix butter with whisk',
#  'add hot milk',
#  '',
#  'add fork',
#  'add salt, shake cayenne',
#  'transfer tater bowl',
#  'Add salt to water',
#  'cut potatoes into quarters',
#  'peel and chopped garlic',
#  'drain water out of pot; stir in butter',
#  'add romano cheese, garlic, dried oregano',
#  'cut it on a diagonal',
#  'cut bread',
#  'add ginger, shoga',
#  'cut potatoes into strainer',
#  'pour hot milk',
#  'season butternut with salt',
#  'Cook carrots',
#  'sizzling onions, garlic',
#  'cook down onions',
#  'cook mushrooms',
#  'break bread',
#  'add tomatoes',
#  'bubble away',
#  'clean prawn',
#  'cut slits',
#  'cut prawns, add fish, soya sauce',
#  'add teriyaki oil, garlic',
#  'marinate mixture',
#  'mix tempura mix flour',
#  'fry the',
#  'dip prawn in bread crumbs; fry prawn',
#  'beat egg, water, whisk in flour',
#  'mix tempura batter',
#  'Press back',
#  'dip shrimp',
#  'drop in',
#  'add warm water, sugar, yeast',
#  'add oil',
#  'keep dough in greased bowl',
#  'cover dough',
#  'shape dough',
#  'add garlic',
#  'add coriander',
#  'add butter',
#  'heat up an item tower',
#  'take dumpling',
#  'add garlic',
#  'roll dough',
#  'flip garlic sticks with water',
#  'flip rice',
#  'chop onions',
#  'slice carrots',
#  'fry onions, carrots, beef mints',
#  'add worcester source and beef',
#  'Boil mixture',
#  'Stir mixture',
#  'boil potatoes',
#  'pour potatoes',
#  'pour milk, butter',
#  'serve masha and mash potatoes',
#  'stir',
#  ' spoon out meat',
#  'spread mashed potato',
#  'spread mashed potato',
#  'get lines in the top',
#  'crush ready salted crisps',
#  'sprinkle mixture on top of cottage pie',
#  'put cottage pie in oven',
#  'melt butter',
#  'combine ingredients',
#  'beat eggs into milk',
#  'whisk in melted butter',
#  'Let the melted butter sit',
#  'mix in milk and egg',
#  'add vanilla extract',
#  'preheat pan',
#  'season griddle',
#  'spread batter',
#  'turn',
#  'add le',
#  'add cloves, turmeric',
#  'add yellow curry powder',
#  'bring paste together',
#  'add oil',
#  'bring sides on',
#  'add jar top',
#  'add oil',
#  'drain the can',
#  'put garbanzo beans in food processor',
#  'throw onion, garlic',
#  'add spices, cayenne pepper',
#  'add baking powder',
#  'add cilantro and parsley',
#  'top with beans',
#  'grind the mixture',
#  'push the machine down',
#  ' pulse the mixture',
#  'stick meat',
#  'throw the machine',
#  'put in lemon juice',
#  'use tablespoon',
#  'drizzle olive oil on',
#  'put olive oil under falafels',
#  'flip bread',
#  'add water to ball',
#  'Drain water from chick peas and feather beans',
#  'add onions, garlic cloves, green pepper',
#  'grind ingredients',
#  'add one',
#  'add baking',
#  'season with salt',
#  'add red pepper',
#  'make bread',
#  'rust under fulgurator',
#  'take falafel',
#  ' spawn mixture',
#  'add oil',
#  'add grape seed oil',
#  'reduce temperature of oil',
#  'wait 30 seconds',
#  'flip bread',
#  'crack egg',
#  'lay it on some people',
#  'cut avocado',
#  'cut up avocado',
#  'Add egg eyeballs to bagel',
#  'whisk in butter',
#  'squeeze in lemon',
#  'sprinkle seasoning',
#  'cook kitchen',
#  'drizzle over ingredients',
#  'add basil',
#  'put corn flour, spelt flour, flour, guar gum powder, hot paprika powder, pepper and turmeric in soy milk',
#  'mix dough',
#  'cut tofu',
#  'stick wooden pins in tofu',
#  'put dough on',
#  'fry smoked tofu',
#  'open cracker egg; get milk',
#  'whisk together',
#  'add ingredients',
#  'add salt',
#  'add flower',
#  'mix oil, baking powder, corn meal',
#  'heat oil',
#  'drain corn dogs',
#  'cut hot dogs',
#  'put little sticks in hot dog',
#  'dip hotdog in batter',
#  'put in oil',
#  'add golden brown color',
#  'drain corn dogs',
#  'serve with mustard',
#  'put butter in van',
#  'put in flower',
#  'add milk',
#  'add salt, pepper',
#  'mix egg',
#  'put in bread',
#  'add sauce',
#  'add pepper',
#  'add cheese',
#  'add capsicum',
#  'add salt, pepper',
#  'refrigerate the mixture',
#  'cook pasta',
#  'add sweet corn',
#  'set aside spring onion, green pepper, yellow pepper',
#  'put salad cream inside',
#  'add green pepper, red pepper',
#  'bring water to a boil',
#  'add fus',
#  'cook pasta',
#  ' combine pasta with cherry tomatoes',
#  'take provolone, salami, sliced pepperoni',
#  'add bell pepper, black olives; add Italian salad, dressing, pimientos',
#  'add pasta salad',
#  'add sugar, saki, beef stock mix, hot chili oil',
#  'add mixture',
#  'cook chicken',
#  'add onions',
#  'add white pepper, salt',
#  'add garlic and mushrooms',
#  'add bean sprouts',
#  'add noodles',
#  'add mail',
#  'add kutsal',
#  'add green onions, beni, shoga',
#  'put bacon in pan',
#  'fold each other back',
#  'flip sandwich over',
#  'pull other sides of the side of',
#  'use a V formation',
#  'fold bacon across',
#  'fold over',
#  'cook sandwich',
#  'throw on cheese',
#  'cover sandwich',
#  'fold sandwich on plate',
#  'add chicken',
#  'take coriander powder',
#  'mix garam masala',
#  'add salt',
#  'make chicken',
#  'keep mixture for 20 minutes',
#  'add onion paste',
#  'prepine onion paste',
#  'put cinnamon sticks, pepper gloves, mustard seeds, human t',
#  'tend onion',
#  'stir mixture',
#  'mix tomato puri',
#  'mix chicken',
#  'make water',
#  'add potatoes',
#  'cook mixture',
#  'slice celery',
#  'slice shikara',
#  'dice dough',
#  'Chop tomatoes',
#  'add cabbage',
#  'add base pan',
#  'add olive oil',
#  'add onion, carrots, mushrooms',
#  'add ham',
#  'add potatoes, flower dried tomatoes, cabbage',
#  'add salt, pepper',
#  'add dried herbs',
#  'add dried basil',
#  'cook in ten minutes',
#  'add tomatoes, peas',
#  'add chicken stock',
#  'add parmesan rind',
#  'put in oven',
#  'add water',
#  'add low sodium low fat chicken broth',
#  'Let cook broth',
#  'put meat in meat',
#  'add chicken tenderloins to broth',
#  'add whole pasta',
#  'add vegetables',
#  'cook mixture',
#  'chop up chicken tenderloins',
#  'add potatoes to soup',
#  '',
#  'turn off flame',
#  'add black pepper',
#  'put burner on low',
#  'cut chicken in half',
#  'stir in',
#  'add sichuan pe',
#  'take spicy bean paste',
#  'take green onion, ground pork',
#  'add ginger, garlic',
#  'take silken tofu',
#  'make cornstarch slurry',
#  'add cornstarch, chicken stock',
#  'put oil',
#  'put garlic in ginger',
#  'add',
#  'turn heat up',
#  'add pork',
#  'put spicy bean paste',
#  'turn heat up',
#  'put chili oil in',
#  'put tofu',
#  'put',
#  'mix soy sauce, spicy sauce, sugar',
#  'add vegetables',
#  'turn off router',
#  'add kosher salt',
#  'sprinkle salt over vegetables',
#  'put ginger, garlic',
#  'get red pepper powder',
#  'add brown sugar, rice vinegar',
#  'put in mixture',
#  'add sesame seeds',
#  'take Italian sausage',
#  'put egg on top',
#  'add Italian bread crumbs',
#  'add onion powder',
#  'add garlic powder, salt',
#  'mix ingredients',
#  'flatten dough',
#  'add pepper',
#  'mix peppers',
#  'put on the baby in refrigerator',
#  'sprinkle oil',
#  'make baseballs',
#  'put meatballs in oven',
#  '',
#  'transfer meat in skillet',
#  'remove parsley',
#  'add tomato sauce',
#  'put meatball inside',
#  'cut shrimp',
#  'drain emma noodles, add shrimp, oil, grated ginger',
#  'season with sugar, soy sauce',
#  'cook salmon noodles; add black pepper, sesame',
#  'place filling on spring roll',
#  'roll mixture of flour, water',
#  'deep fry spring rolls',
#  'add bell peppers, onion',
#  'add olive oil, spices, skewers',
#  'Dice up mushrooms',
#  'marinate onion chunk vegetables',
#  'cr',
#  'marinate mixture',
#  'add salt, parsley, red',
#  'fill out the grill',
#  'leave lid open',
#  'add garlic, rosemary',
#  'get rid of skins',
#  'grind chicken',
#  'add orange',
#  'squeeze lemon juice',
#  'add salt',
#  'add olive oil',
#  'add chicken',
#  'put in fridge',
#  'rigerate chicken',
#  'take chicken out of fridge',
#  'add onion',
#  'cut chicken',
#  'add zucchini, peppers',
#  'add onion',
#  'add olive oil',
#  'turn mine down',
#  'add honey',
#  'let lemon rosemary, garlic',
#  'add sugar',
#  'add bourbon',
#  'add orange',
#  'add sugar',
#  'drop ice cubes in glasses',
#  'take olive oil',
#  'add aromatics, garlic, tomatoes',
#  'pour in vodka, cream',
#  'boil vodka',
#  'cook chicken on one side',
#  'reduce heat to low',
#  'mix sauce',
#  'add hoisin sauce, peanut butter, ho',
#  'add sugar water, garlic powder',
#  'stir mixture',
#  'squeeze in lime',
#  'add chopped garlic',
#  'add chilli peppers',
#  'put in fridge',
#  'add tofu, bean sprouts',
#  'add lettuce, coriander, mint and cilantro',
#  'cut shrimp in half',
#  'add lettuce, cilantro, bean sprouts',
#  'add cooked rice, shrimp, slices of homemade vietnamese ham',
#  'layer tofu',
#  'add lettuce, mint',
#  'add cilantro',
#  'add ham, tofu',
#  'add shrimp',
#  'cut proms',
#  'wash pasta under cold water',
#  'cut cucumber',
#  'wash vegetables',
#  'Dip rice paper into water',
#  'place vegetables on center',
#  'make hoisin sauce',
#  'add oil',
#  'add garlic, whoreson sauce',
#  'Add peanut butter, sugar',
#  'Add boiling water to thermostat',
#  'put cucumber in tabouli',
#  'take grape tomatoes',
#  'add carrot, green onions',
#  'add mint and parsley',
#  'add dried and fresh herbs',
#  'add olive oil, salt, black pepper',
#  'chop cauliflower',
#  'take cucumber, cherry tomatoes, lemon juice',
#  'take olive oil, garlic, parsley, sea salt, black pepper',
#  'toss cauliflower into food processor',
#  'add cauliflower rice',
#  'add cucumber, cherry tomatoes, scallions',
#  'add mint, parsley, minced garlic',
#  'add sea salt',
#  'toss mixture',
#  'add lemon juice',
#  'add olive oil',
#  'toss together ingredients',
#  'add spring onions, scallions, brown onion',
#  'add tomatoes',
#  'add lemon juice, parsley',
#  'add olive oil',
#  'add boiling water',
#  'place bread on',
#  'add onion, chop tomatoes',
#  'add salt, pepper, olive oil, lemon trees',
#  'squeeze lemon',
#  'toss potatoes',
#  'take bezoar, garlic lemon, tahini, roasted red peppers',
#  'use ground cumin salt, cayenne pepper',
#  'cut garlic and roasted red peppers',
#  'put chick peas in food processor; process ingredients',
#  'add hummus',
#  'add garlic, ginger',
#  'take silica from nettles',
#  'add plum paste',
#  'add salt, curry powder',
#  'blend the',
#  'add cayenne',
#  'add coconut oil',
#  ' garnish with parsley',
#  'get pan',
#  'add soy bean puree',
#  'add chilli chilies, ginger',
#  'take broccoli',
#  'add ginger, cafe lime',
#  'cook broccoli',
#  'add sesame seed oil',
#  'melt butter',
#  'use bread sticks',
#  'put bread in pan',
#  'add cheddar cheese',
#  'place sharp cheddar cheese',
#  'add pizza sauce',
#  'spread pepperoni',
#  'take turkey pepperoni',
#  'add mozzarella',
#  'add mushrooms, onions, black olive',
#  'put cheese together',
#  'take rice',
#  'add nor',
#  'dip hands in water',
#  'spread rice all the sides',
#  'spread mail on sushi',
#  'take avocado',
#  'take surimi crab',
#  'put cucumber on top',
#  'fold dough',
#  'take the slicer',
#  'cut sushi',
#  'slice cucumbers, avocado slice tamago',
#  'add sushi rice anna makezu',
#  'spread sushi on nori seaweed',
#  'spread rice on nori seaweed',
#  'flip over on side of nori seaweed',
#  'spread mayonnaise, roll seaweed',
#  'spread masago',
#  'add sesame greens',
#  'get knife',
#  'cut sushi',
#  'add safflower oil',
#  'add wire rack',
#  'use deep fat thermometer',
#  'keep oil up to four degrees',
#  'cut through the skin',
#  'bend the',
#  'place wings in pot',
#  'pull the wings out of oil',
#  'add red sauce',
#  'bring heat to simmer',
#  'add butter',
#  'add cold butter',
#  'turn off heat',
#  'put chicken wings in bowl',
#  'Add sauce to bowl',
#  'coat wings',
#  'add blue cheese, salt and pepper',
#  'let wingdings soak in saltwater',
#  'season with parsley flakes',
#  'add black pepper',
#  'add garlic powder, seasoning salt',
#  'add catch up and hot sauce',
#  'fry wings',
#  'need butter',
#  'add pepper',
#  'add garlic',
#  'add seasoning',
#  'season wingdings',
#  'get hot',
#  'set wings aside',
#  'add butter',
#  'reduce heat to low heat',
#  'add parsley flakes, brazil the buffalo sauce',
#  'add coarse kosher salt',
#  'sprinkle chicken',
#  'season chicken with lowerys',
#  'add garlic powder',
#  'add onion powder',
#  'take unsalted butter',
#  'wash chicken in vinegar, kosher salt',
#  'Drain excess water off the chick',
#  'sprinkle garlic powder, sprinkle',
#  'pour hot sauce',
#  'add wings',
#  'cut cabbage',
#  'submerge cabbage',
#  'leave cabbage for a week',
#  'add salt',
#  'sprinkle cabbage',
#  'add salt to cabbage',
#  'toss cabbage',
#  'squeeze dough',
#  'add water',
#  'keep cabbage submerged',
#  'seal cabbage',
#  'let air out',
#  'throw dish towel on top',
#  'add channel',
#  'keep shiners in water; pressure cook',
#  'add cinnamon',
#  'add black cardamom, star anus',
#  'add flame to medium',
#  'add ginger paste',
#  'add chopped tomatoes',
#  'add garam masala',
#  'add salt',
#  'add coriander powder',
#  'add chilli powder, dry ginger powder',
#  'cook at low flame',
#  'cover with lid; cook chopped tomatoes',
#  'add carom seeds, drain',
#  'add pomegranate seeds powder',
#  'add dry mango powder',
#  'add china water',
#  'mix mixture',
#  'cover with lid; cook',
#  'add kasoori, methi',
#  'crush chicken',
#  'cover with lid; cook mixture',
#  'put off flame',
#  'make portera',
#  'add sushi, semolina',
#  'add sugar, baking soda',
#  'put in yogurt',
#  'add water',
#  'bring together ingredients',
#  'coat oil',
#  'rest at a prom place',
#  'put oil in pressure cooker',
#  'add chopped onion',
#  'wait onion until golden brown',
#  'cook ginger garlic',
#  'add charlie',
#  'make cumin powder, coriander, amchur, powder, red chilli powder',
#  'Cook chana masala',
#  'add chopped tomatoes',
#  'add water',
#  'add red chilli powder',
#  'cook chopped tomatoes',
#  'add chicken pace',
#  'put water',
#  'cook until eight whistles',
#  'roll balls',
#  'get chicken out',
#  'add garlic and sesame seed oil',
#  'add fish sauce',
#  'add salt',
#  'set aside to marinate',
#  'put in refrigerator',
#  'pickled carrot',
#  'add rice wine vinegar',
#  'get chicken on stove',
#  'cut sandwich',
#  'lay chicken on the inside',
#  'add cilantro',
#  'top sandwich',
#  'add',
#  'add elbow',
#  'cook pasta',
#  'add cheese',
#  'beat eggs',
#  'add evaporated milk',
#  'add half and half',
#  'add salt',
#  'Ground pepper',
#  'stir the mixture',
#  'add elbow pasta',
#  'sprinkle oven with nonstick spray',
#  'add macaroni mixture',
#  'bake mac and cheese',
#  'fill pot with water, sprinkling ice',
#  'add salt',
#  'add olive oil',
#  'heat pan',
#  'add butter',
#  'add flower, cook mixture',
#  'whisk milk',
#  'cook mixture',
#  'drain mixture onto plate',
#  'take black pepper',
#  'season with salt',
#  'add grated cheddar',
#  'stir mixture',
#  'drain pan',
#  'add creamy cheese sauce',
#  'mix ingredients into casserole dish',
#  'add sauce',
#  'add bread crumbs, drizzle with olive oil',
#  'put all meat in zip lock bag',
#  'squeeze citrus shells',
#  'put all the eggs in',
#  'remove air from the bag',
#  'put marinade in fridge',
#  'sear the mixture',
#  'take two minutes',
#  'turn marinade',
#  'set syrup on plate',
#  'cook saaf',
#  'chop marinade',
#  'add guacamole',
#  'add lettuce, green onions, mexican cheese',
#  'add tomato, onion, daisy',
#  'take chopped onion',
#  'add ground beef',
#  'cook for five minutes',
#  'add onion',
#  'cook onions',
#  'add salts',
#  'add cornstarch',
#  'simmer mixture',
#  'boil potatoes',
#  ...]

# %%
_predictions = [prediction for prediction in predictions_list]
predictions_list = _predictions

# %%
results_df = pd.DataFrame({'text': text_list,
                'summary': summary_list,
                'prediction': predictions_list,
                'true_positives': true_positive_list,
                'num_predicted': num_predicted_list,
                'num_gold': num_gold_list
                })

# %%
results_df.to_csv(str(LOG_SAVE_DIR / 'val_performance.csv'), index=False)

# %%
pd.read_csv(str(LOG_SAVE_DIR / 'val_performance.csv'))
# Out:
#                                                    text  \
# 0     so we ' ve placed the dough directly into the ...
# 1     and then we give the pizza a flip as i ' ve re...
# 2     but that 's what we do anyway , we sprinkle th...
# 3     we just give a squish with our palm and make t...
# 4     we dimple the rest of the pizza , moving the p...
# ...                                                 ...
# 1056  so of vegetable oil into a large , deep and he...
# 1057  best , if you have one as one holds , and dist...
# 1058  the chicken pieces in the skillet and fry , th...
# 1059  pieces , several times during the cooking time...
# 1060                            anyway , you season it.
#
#                                               summary  \
# 0                         place dough in caputo flour
# 1                                          flip dough
# 2                                sprinkle the surface
# 3              squish dough with palm; flatten center
# 4     dimple the rest of pizza; move the pizza around
# ...                                               ...
# 1056                                      oil skillet
# 1057                               fry at 365 degrees
# 1058                               fry for 20 minutes
# 1059                                    drain chicken
# 1060                                   season chicken
#
#                        prediction  true_positives  num_predicted  num_gold
# 0     place dough in caputo flour               5              5         5
# 1                      flip pizza               1              2         2
# 2            sprinkle the surface               3              3         3
# 3                    squish pizza               1              2         6
# 4                    dimple pizza               2              2         8
# ...                           ...             ...            ...       ...
# 1056            add vegetable oil               1              3         2
# 1057                     heat oil               0              2         4
# 1058   fry chicken for 15 minutes               3              6         4
# 1059                drain chicken               2              2         2
# 1060                  season meat               1              2         2
#
# [1061 rows x 6 columns]

# %%
precision = round(total_true_pos / total_num_predicted, 2)
recall = round(total_true_pos / total_num_gold, 2)
f1 = round(2*(precision*recall) / (precision+recall), 2)

print(f"Total true positives (predicted words overlap with gold words): {total_true_pos}")
print(f"Total predicted words: {total_num_predicted}")
print(f"Total gold words: {total_num_gold}")
print(f"Precision: {precision}, Recall: {recall}, F1: {f1}")
# Out:
# Total true positives (predicted words overlap with gold words): 1895
# Total predicted words: 3490
# Total gold words: 4154
# Precision: 0.54, Recall: 0.46, F1: 0.5

# %% [markdown]
# ## Generate Knowledge Extraction metrics based on best Key-clip Prediction model's predictions

# %%
def best_keyclip_prediction_true_positives(row):
    return row['true_positives'] if row['IsPredUseful'] == 1 else 0

def generate_metrics_from_master_and_val_df(master_df, val_df):
  combined_df = pd.merge(master_df, val_df, left_on='Sentence', right_on='text', how='inner')
  combined_df['best_kc_pred_true_positives'] = combined_df.apply(lambda row: best_keyclip_prediction_true_positives(row), axis=1)
  total_num_gold = combined_df['num_gold'].sum()
  total_num_predicted = combined_df['num_predicted'].sum()
  total_true_pos = combined_df['best_kc_pred_true_positives'].sum()
  precision = round(total_true_pos / total_num_predicted, 2)
  recall = round(total_true_pos / total_num_gold, 2)
  f1 = round(2*(precision*recall) / (precision+recall), 2)

  print(f"Total true positives (predicted words overlap with gold words): {total_true_pos}")
  print(f"Total predicted words: {total_num_predicted}")
  print(f"Total gold words: {total_num_gold}")
  print(f"Precision: {precision}, Recall: {recall}, F1: {f1}")
  
  return precision, recall, f1

# %%
master_df = pd.read_pickle(DATA_DIR / 'full_master_updated.pkl')
val_df = pd.read_csv(str(LOG_SAVE_DIR / 'val_performance.csv'))

# %%
generate_metrics_from_master_and_val_df(master_df, val_df)
# Out:
# Total true positives (predicted words overlap with gold words): 532
# Total predicted words: 1278
# Total gold words: 1544
# Precision: 0.42, Recall: 0.34, F1: 0.38
# (0.42, 0.34, 0.38)
